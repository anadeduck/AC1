# %% [markdown]
# <a href="https://colab.research.google.com/github/anadeduck/AC1/blob/main/AC_plataformas_cognitivas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
b= requests.get("https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos?sol=1000&MAHLI&api_key=jad1cSEO0ervlKbbgJU8y540I7gzgbKzhUtbdvqR")
print(b)
b.json()
resposta=b.json()
cont=0
for c in resposta['photos']:
  cont+=1
  print(f'O link da {cont} foto é:', c['img_src'])
# Out:
# <Response [200]>
# O link da 1 foto é: http://mars.jpl.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/01000/opgs/edr/fcam/FLB_486265257EDR_F0481570FHAZ00323M_.JPG
# O link da 2 foto é: http://mars.jpl.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/01000/opgs/edr/fcam/FRB_486265257EDR_F0481570FHAZ00323M_.JPG
# O link da 3 foto é: http://mars.jpl.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/01000/opgs/edr/rcam/RLB_486265291EDR_F0481570RHAZ00323M_.JPG
# O link da 4 foto é: http://mars.jpl.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/01000/opgs/edr/rcam/RRB_486265291EDR_F0481570RHAZ00323M_.JPG
# O link da 5 foto é: http://mars.jpl.nasa.gov/msl-raw-images/msss/01000/mcam/1000MR0044631300503690E01_DXXX.jpg
# O link da 6 foto é: http://mars.jpl.nasa.gov/msl-raw-images/msss/01000/mcam/1000ML0044631300305227E03_DXXX.jpg
# O link da 7 foto é: http://mars.jpl.nasa.gov/msl-raw-images/msss/01000/mcam/1000MR0044631290503689E01_DXXX.jpg
# ...
